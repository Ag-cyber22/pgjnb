# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Anjelica Grieser**
# Full Stack Data Scientist

# %% [markdown]
# *I am interested in data science because I'm looking for a career change. I'd like to do something dynamic that pays for the time and effort I pour into it.*

# %% [markdown]
# ### Find the difference of 2 minus 1.

# %%
2-1
# Out:
# 1

# %% [markdown]
# * this is a bullet list
# * this is a bullet list
# * this is a bullet list
# * this is a bullet list
# 1. this is a numbered list
# 2. this is a numbered list
# 3. this is a numbered list
# 4. this is a numbered list
#
# `highlight some code like this!`
